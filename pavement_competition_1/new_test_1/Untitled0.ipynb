# %%
# %cd '/content/drive/MyDrive/pavement_competition_1/new_test_1'
# Out:
# /content/drive/MyDrive/pavement_competition_1/new_test_1

# %%
! git clone -b main_dev https://github.com/UM-Titan/DSPS.git
# Out:
# Cloning into 'DSPS'...
# remote: Enumerating objects: 809, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 809 (delta 32), reused 25 (delta 12), pack-reused 752
# Receiving objects: 100% (809/809), 378.77 MiB | 15.76 MiB/s, done.
# Resolving deltas: 100% (184/184), done.
# Checking out files: 100% (150/150), done.

# %%
! cd DSPS

# %%
# !ls
# Out:
# DSPS  Untitled0.ipynb
